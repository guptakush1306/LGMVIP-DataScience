# %% [markdown]
# # Data Science Intern-LetsGrowMore
# # Author-Kushara Gupta
# # Topic-Iris Flower Classification ML Project

# %% [markdown]
# ``This is a dataset of flower with their length,width,height and we have to do machine learning models on this and get good accuracy``

# %% [markdown]
# # Task1- Predict the species of flowers

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/irissdata/Iris.csv
# /kaggle/input/irissdata/database.sqlite
# /kaggle/input/lgmtaskk1/iris.names

# %% [markdown]
# ``Importing suitable libraries``

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy as sp

# %% [markdown]
# ``Reading the csv file``

# %%
df=pd.read_csv('../input/irissdata/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info() #shows information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.shape #describe the shape of the dataset
# Out:
# (150, 6)

# %%
df.columns #displays all columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()  #displaying the sum of all null
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.isnull().any() #finding the sum of all elements and storing it to zero
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.isnull().all()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.value_counts() #finding the value
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %% [markdown]
# # Visualisations

# %% [markdown]
# ``ScatterPlot``

# %%
df.plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm')
plt.plot()
# Out:
# []

# %% [markdown]
# ``Barplot``

# %%
df.plot(kind='bar',x='SepalLengthCm',y='PetalLengthCm')
plt.plot()
# Out:
# []

# %% [markdown]
# ``KDE Plot``

# %%
df.plot(kind='kde',x='SepalLengthCm',y='PetalWidthCm')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ``Joint plot``

# %%
sns.jointplot(x='SepalWidthCm',y='PetalLengthCm',data=df)
plt.plot()
# Out:
# []

# %%
sns.kdeplot(x='SepalWidthCm',y='PetalWidthCm',data=df)
plt.plot()
# Out:
# []

# %% [markdown]
# ``Boxplot``

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Species',y='PetalWidthCm',data=df)
plt.xticks(rotation=50)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Species',y='PetalLengthCm',data=df)
plt.xticks(rotation=50)
plt.plot()
# Out:
# []

# %% [markdown]
# ``Violen Plot``

# %%
sns.violinplot(x='Species',y='SepalLengthCm',data=df)
plt.plot()
# Out:
# []

# %% [markdown]
# ``Pairplot``

# %%
sns.pairplot(df.drop('Id',axis=1),hue='Species')

# %%
df.tail()  #displaying the last elements
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ``Heatmap``

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,linewidths=3)
plt.show()

# %% [markdown]
# ``Calculating the subplots using all the elements``

# %%
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.histplot(df['SepalLengthCm'],color='blue',kde=True).set_title('Sepal Length vs counts')
plt.subplot(2,2,2)
sns.histplot(df['SepalWidthCm'],color='green',kde=True).set_title('Sepal WIdth vs counts')
plt.subplot(2,2,3)
sns.histplot(df['PetalLengthCm'],color='grey',kde=True).set_title('Petal length vs counts')
plt.subplot(2,2,4)
sns.histplot(df['PetalWidthCm'],color='red',kde=True).set_title('Petal Width vs counts')
plt.plot()
# Out:
# []

# %% [markdown]
# ``Calculate the barplot of all the elements``

# %%
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.barplot(x='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,2)
sns.barplot(x='Species',y='SepalWidthCm',data=df)
plt.subplot(2,2,3)
sns.barplot(x='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,4)
sns.barplot(x='Species',y='PetalWidthCm',data=df)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,18))
plt.subplot(2,2,1)
sns.countplot(df['SepalLengthCm'],color='blue').set_title('Sepal Length vs counts')
plt.subplot(2,2,2)
sns.countplot(df['SepalWidthCm'],color='green').set_title('Sepal WIdth vs counts')
plt.subplot(2,2,3)
sns.countplot(df['PetalLengthCm'],color='grey').set_title('Petal length vs counts')
plt.subplot(2,2,4)
sns.countplot(df['PetalWidthCm'],color='red').set_title('Petal Width vs counts')
plt.plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ``Dropping the element``

# %%
x=df.drop(columns='Species')
y=df['Species']

# %% [markdown]
# ``Training and testing data``

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 120
# 30
# 120
# 30

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# # 1- KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print('Accuracy\n',accuracy_score(y_test,y_pred)*100)
print('Confusin Matrix\n',confusion_matrix(y_test,y_pred))
print('Classification Report\n',classification_report(y_test,y_pred))
# Out:
# Accuracy
#  100.0
# Confusin Matrix
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
# Classification Report
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# # 2-Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=5,random_state=0,criterion='entropy')
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=0)

# %%
y_pred=dt.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print('Accuracy\n',accuracy_score(y_test,y_pred)*100)
print('Confusin Matrix\n',confusion_matrix(y_test,y_pred))
print('Classification Report\n',classification_report(y_test,y_pred))
# Out:
# Accuracy
#  96.66666666666667
# Confusin Matrix
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  1  5]]
# Classification Report
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.83      0.91         6
#
#        accuracy                           0.97        30
#       macro avg       0.98      0.94      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # 3- Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score,mean_squared_error
print('Accuracy\n',accuracy_score(y_test,y_pred)*100)
print('Confusin Matrix\n',confusion_matrix(y_test,y_pred))
print('Classification Report\n',classification_report(y_test,y_pred))
print('Training score',rfc.score(x_train,y_train))
# Out:
# Accuracy
#  100.0
# Confusin Matrix
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
# Classification Report
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# Training score 1.0

# %% [markdown]
# # 4-Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier()
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred=ada.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score,mean_squared_error
print('Accuracy\n',accuracy_score(y_test,y_pred)*100)
print('Confusin Matrix\n',confusion_matrix(y_test,y_pred))
print('Classification Report\n',classification_report(y_test,y_pred))
print('Training score',rfc.score(x_train,y_train))
# Out:
# Accuracy
#  96.66666666666667
# Confusin Matrix
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  1  5]]
# Classification Report
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.93      1.00      0.96        13
#  Iris-virginica       1.00      0.83      0.91         6
#
#        accuracy                           0.97        30
#       macro avg       0.98      0.94      0.96        30
#    weighted avg       0.97      0.97      0.97        30
#
# Training score 1.0

# %% [markdown]
# # 5-Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score,mean_squared_error
print('Accuracy\n',accuracy_score(y_test,y_pred)*100)
print('Confusin Matrix\n',confusion_matrix(y_test,y_pred))
print('Classification Report\n',classification_report(y_test,y_pred))
print('Training score',rfc.score(x_train,y_train))
# Out:
# Accuracy
#  100.0
# Confusin Matrix
#  [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
# Classification Report
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00         6
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# Training score 1.0

# %% [markdown]
# # Here from the above Machine Learning Models we are getting 100% accuracy which is a great output to get
